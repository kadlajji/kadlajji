# %%
# Prepare a model for glass classification using KNN

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv('C:\\Users\\kkdk0001\\Desktop\\DA\\DS\\Assignments\\KNN\\glass.csv')

# %%
df.head(2)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df.shape
# Out:
# (214, 10)

# %%
df.iloc[:,0:9]
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
df.iloc[:,[9]]
# Out:
#      Type
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 209     7
# 210     7
# 211     7
# 212     7
# 213     7
#
# [214 rows x 1 columns]

# %%
x=df.iloc[:,0:9]
x.head(2)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0

# %%
y=df.iloc[:,[9]]
y.head(2)
# Out:
#    Type
# 0     1
# 1     1

# %%
# Normalizing using Min Max

# %%
x=(x-x.min())/(x.max()-x.min())

# %%
x
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.432836  0.437594  1.000000  0.252336  0.351786  0.009662  0.308550
# 1    0.283582  0.475188  0.801782  0.333333  0.521429  0.077295  0.223048
# 2    0.220808  0.421053  0.790646  0.389408  0.567857  0.062802  0.218401
# 3    0.285777  0.372932  0.821826  0.311526  0.500000  0.091787  0.259294
# 4    0.275241  0.381955  0.806236  0.295950  0.583929  0.088567  0.245353
# ..        ...       ...       ...       ...       ...       ...       ...
# 209  0.223003  0.512782  0.000000  0.806854  0.500000  0.012882  0.348513
# 210  0.250219  0.630075  0.000000  0.529595  0.580357  0.000000  0.276022
# 211  0.417032  0.545865  0.000000  0.538941  0.644643  0.000000  0.279740
# 212  0.235294  0.548872  0.000000  0.514019  0.678571  0.000000  0.283457
# 213  0.261633  0.526316  0.000000  0.557632  0.633929  0.000000  0.296468
#
#            Ba   Fe
# 0    0.000000  0.0
# 1    0.000000  0.0
# ...

# %%
# Grid Search for Finding Optimum K value

# %%
from sklearn.model_selection import GridSearchCV

# %%
x.a=x.values
# Out:
# C:\Users\kkdk0001\AppData\Local\Temp/ipykernel_23548/626528881.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.a=x.values

# %%
x.a
# Out:
# array([[0.43283582, 0.43759398, 1.        , ..., 0.30855019, 0.        ,
#         0.        ],
#        [0.28358209, 0.47518797, 0.80178174, ..., 0.22304833, 0.        ,
#         0.        ],
#        [0.22080773, 0.42105263, 0.79064588, ..., 0.21840149, 0.        ,
#         0.        ],
#        ...,
#        [0.41703248, 0.54586466, 0.        , ..., 0.27973978, 0.52063492,
#         0.        ],
#        [0.23529412, 0.54887218, 0.        , ..., 0.28345725, 0.4984127 ,
#         0.        ],
#        [0.26163301, 0.52631579, 0.        , ..., 0.2964684 , 0.53015873,
#         0.        ]])

# %%
y.a=y.values
# Out:
# C:\Users\kkdk0001\AppData\Local\Temp/ipykernel_23548/3714950428.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   y.a=y.values

# %%
n_neighbors= np.array(range(1,50))

# %%
param_grid=dict(n_neighbors=n_neighbors)

# %%
model=KNeighborsClassifier()

# %%
grid=GridSearchCV(estimator=model,param_grid=param_grid)
grid.fit(x,y)
# Out:
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.6311184939091916
# {'n_neighbors': 5}

# %%
# Visulizing CV results

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
k_range=range(1,50)
k_scores=[]
for k in k_range:
    knn=KNeighborsClassifier(n_neighbors=k)
    scores=cross_val_score(knn,x.a,y.a,cv=5)
    k_scores.append(scores.mean())
# Out:
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
plt.plot(k_range,k_scores)
plt.xlabel('K_Range')
plt.ylabel('Cross_Validation_Score')
# Out:
# Text(0, 0.5, 'Cross_Validation_Score')

# %%
# The best K value is 5

# %%
# Final Model

# %%
Final_Model=KNeighborsClassifier(n_neighbors=5)
num_folds=20
kfold=KFold(n_splits=20)

# %%
Results=cross_val_score(Final_Model,x,y,cv=kfold)
# Out:
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
print(Results.mean())
# Out:
# 0.5518181818181819

# %%
# Squareroot Transformation

# %%
x.sqrt=np.sqrt(x)
# Out:
# C:\Users\kkdk0001\AppData\Local\Temp/ipykernel_23548/1098766962.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x.sqrt=np.sqrt(x)

# %%
x.sqrt
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.657903  0.661509  1.000000  0.502331  0.593115  0.098295  0.555473
# 1    0.532524  0.689339  0.895423  0.577350  0.722100  0.278019  0.472280
# 2    0.469902  0.648886  0.889183  0.624026  0.753563  0.250603  0.467334
# 3    0.534581  0.610682  0.906546  0.558146  0.707107  0.302964  0.509209
# 4    0.524635  0.618025  0.897906  0.544013  0.764152  0.297602  0.495331
# ..        ...       ...       ...       ...       ...       ...       ...
# 209  0.472232  0.716088  0.000000  0.898250  0.707107  0.113501  0.590350
# 210  0.500219  0.793773  0.000000  0.727733  0.761812  0.000000  0.525378
# 211  0.645781  0.738827  0.000000  0.734126  0.802897  0.000000  0.528904
# 212  0.485071  0.740859  0.000000  0.716951  0.823754  0.000000  0.532407
# 213  0.511501  0.725476  0.000000  0.746748  0.796196  0.000000  0.544489
#
#            Ba   Fe
# 0    0.000000  0.0
# 1    0.000000  0.0
# ...

# %%
n_neighbors= np.array(range(1,50))
param_grid=dict(n_neighbors=n_neighbors)
model=KNeighborsClassifier()
gridsq=GridSearchCV(estimator=model,param_grid=param_grid)
gridsq.fit(x.sqrt,y)
# Out:
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
print(gridsq.best_score_)
print(gridsq.best_params_)
# Out:
# 0.6683277962347729
# {'n_neighbors': 3}

# %%
# Squareroot Model

# %%
Sqrt_Model=KNeighborsClassifier(n_neighbors=3)
num_folds=20
kfold=KFold(n_splits=20)

# %%
Results1=cross_val_score(Sqrt_Model,x.sqrt,y,cv=kfold)
# Out:
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\kkdk0001\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:200: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
print(Results1.mean())
# Out:
# 0.5745454545454546

# %%
# Implement a KNN model to classify the animals in to categorie

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Zoo=pd.read_csv('C:\\Users\\kkdk0001\\Desktop\\DA\\DS\\Assignments\\KNN\\Zoo.csv')
zoo=Zoo.iloc[:,1:]

# %%
from sklearn.model_selection import train_test_split
train,test=train_test_split(zoo,test_size=0.3,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier as KNC

# %%
acc=[]
for i in range(3,50,2):
    neigh=KNC(n_neighbors=i)
    neigh.fit(train.iloc[:,0:16],train.iloc[:,16])
    train_acc=np.mean(neigh.predict(train.iloc[:,0:16])==train.iloc[:,16])
    test_acc=np.mean(neigh.predict(test.iloc[:,0:16])==test.iloc[:,16])
    acc.append([train_acc,test_acc])

# %%
plt.plot(np.arange(3,50,2),[i[0] for i in acc],'bo-')
plt.plot(np.arange(3,50,2),[i[1] for i in acc],'ro-')
plt.legend(['train','test'])

# %%
neigh=KNC(n_neighbors=5)
neigh.fit(train.iloc[:,0:16],train.iloc[:,16])
# Out:
# KNeighborsClassifier()

# %%
train_acc=np.mean(neigh.predict(train.iloc[:,0:16])==train.iloc[:,16])
test_acc=np.mean(neigh.predict(test.iloc[:,0:16])==test.iloc[:,16])
train_acc
print('Test Accuracy is',round(test_acc*100),"%")
# Out:
# Test Accuracy is 94 %
