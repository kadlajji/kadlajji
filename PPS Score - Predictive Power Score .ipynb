# %%
#!pip install ppscore

# %%
import ppscore as pps
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\kkdk0001\\Desktop\\DA\\DS\\Project 1 (P162) - Teli Churn\\telecommunications_churn.csv')

# %%
df.head(2)
# Out:
#    account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0             128                1                   25     265.1
# 1             107                1                   26     161.6
#
#    evening_mins  night_mins  international_mins  customer_service_calls  \
# 0         197.4       244.7                10.0                       1
# 1         195.5       254.4                13.7                       1
#
#    international_plan  day_calls  day_charge  evening_calls  evening_charge  \
# 0                   0        110       45.07             99           16.78
# 1                   0        123       27.47            103           16.62
#
#    night_calls  night_charge  international_calls  international_charge  \
# 0           91         11.01                    3                   2.7
# 1          103         11.45                    3                   3.7
#
#    total_charge  churn
# 0         75.56      0
# 1         59.24      0

# %%
pps.score(df,"voice_mail_plan",'voice_mail_messages')
# Out:
# {'x': 'voice_mail_plan',
#  'y': 'voice_mail_messages',
#  'ppscore': 0.7939636799321865,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 8.099009900990099,
#  'model_score': 1.6686901961927858,
#  'model': DecisionTreeRegressor()}

# %%
# PPS score for complete dataframe

# %%
pps.matrix(df)
# Out:
#                   x                     y   ppscore            case  \
# 0    account_length        account_length  1.000000  predict_itself
# 1    account_length       voice_mail_plan  0.000000      regression
# 2    account_length   voice_mail_messages  0.000000      regression
# 3    account_length              day_mins  0.000000      regression
# 4    account_length          evening_mins  0.000000      regression
# ..              ...                   ...       ...             ...
# 356           churn          night_charge  0.000606      regression
# 357           churn   international_calls  0.000000      regression
# 358           churn  international_charge  0.000581      regression
# 359           churn          total_charge  0.011573      regression
# 360           churn                 churn  1.000000  predict_itself
#
#      is_valid_score               metric  baseline_score  model_score  \
# 0              True                 None        0.000000     1.000000
# 1              True  mean absolute error        0.276628     0.395590
# 2              True  mean absolute error        8.099010    11.581329
# 3              True  mean absolute error       43.522472    45.287552
# 4              True  mean absolute error       40.468377    41.955037
# ..              ...                  ...             ...          ...
# 356            True  mean absolute error        1.818518     1.817416
# 357            True  mean absolute error        1.798380     1.874422
# 358            True  mean absolute error        0.589700     0.589357
# 359            True  mean absolute error        8.347183     8.250579
# 360            True                 None        0.000000     1.000000
#
#                        model
# 0                       None
# 1    DecisionTreeRegressor()
# 2    DecisionTreeRegressor()
# 3    DecisionTreeRegressor()
# 4    DecisionTreeRegressor()
# ..                       ...
# 356  DecisionTreeRegressor()
# 357  DecisionTreeRegressor()
# 358  DecisionTreeRegressor()
# 359  DecisionTreeRegressor()
# 360                     None
#
# [361 rows x 9 columns]
